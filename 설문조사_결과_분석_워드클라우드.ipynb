# %% [markdown]
# <a href="https://colab.research.google.com/github/Jieunlee-svg/dataanalysis_/blob/main/%EC%84%A4%EB%AC%B8%EC%A1%B0%EC%82%AC_%EA%B2%B0%EA%B3%BC_%EB%B6%84%EC%84%9D_%EC%9B%8C%EB%93%9C%ED%81%B4%EB%9D%BC%EC%9A%B0%EB%93%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 설치
# !pip install --upgrade pip
# !pip install nltk konlpy wordcloud
# !apt-get -qq install fonts-nanum

# 폰트 설정
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
plt.rc('font', family='NanumGothic')

# 형태소 분석기
from konlpy.tag import Okt
okt = Okt()

# 예시 텍스트
text = "워드클라우드 테스트입니다. 워드클라우드는 시각화에 좋아요."

# 명사 추출
nouns = okt.nouns(text)

# 빈도수 계산
from nltk import FreqDist
freq = FreqDist(nouns)

# 워드클라우드 생성
from wordcloud import WordCloud

wordcloud = WordCloud(font_path='/usr/share/fonts/truetype/nanum/NanumGothic.ttf',
                      background_color='white',
                      width=800, height=400).generate_from_frequencies(freq)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 3.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 27.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [konlpy]
# ...
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 126281 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6374ce38-dae9-43b7-96cf-8e1515d27309" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6374ce38-dae9-43b7-96cf-8e1515d27309">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_excel('공유하는사람_wordclouds.xlsx')
df.head()
# Out:
#                Q14(TEXT)
# 0          신체적 정신적 건강 모두
# 1                건강검진 결과
# 2                   종합검진
# 3                    NaN
# 4  관련질환의 상태나 관리 내용 위급상황등

# %%
df = df.fillna('')  # 결측값 제거
all_text = ' '.join(df['Q14(TEXT)'])

# %%
from konlpy.tag import Okt
okt = Okt()
nouns = okt.nouns(all_text)

# %%
# 자주 등장하지만 의미 없는 단어 추가
stopwords = ['정보', '건강', '데이터', '및', '관련', '등','그냥','현재','상태']
words = [word for word in nouns if word not in stopwords and len(word) > 1]

# %%
from nltk import FreqDist
from wordcloud import WordCloud
import matplotlib.pyplot as plt

freq = FreqDist(words)

# 한글 폰트 설정
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'

wordcloud = WordCloud(font_path=font_path,
                      background_color='white',
                      width=800, height=400).generate_from_frequencies(freq)

plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Health information you would like to share', fontsize=20)
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-469d665e-333c-46ea-9739-9878451534cd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-469d665e-333c-46ea-9739-9878451534cd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_excel('공유받는사람_wordclouds.xlsx')
df.head()
# Out:
#                   Q5(TEXT)
# 0                   종합검진결과
# 1  가족몸이나 내몸에 무슨병이 있는지 궁금하다
# 2                 아픈곳이있으신가
# 3          뇌졸중,고혈압,심근경색,당뇨
# 4                     치매 암

# %%
df = df.fillna('')  # 결측값 제거
all_text = ' '.join(df['Q5(TEXT)'])
from konlpy.tag import Okt
okt = Okt()
nouns = okt.nouns(all_text)
# 자주 등장하지만 의미 없는 단어 추가
stopwords = ['정보', '건강', '데이터', '및', '관련', '등','그냥','현재','상태']
words = [word for word in nouns if word not in stopwords and len(word) > 1]

# %%
from nltk import FreqDist
from wordcloud import WordCloud
import matplotlib.pyplot as plt

freq = FreqDist(words)

# 한글 폰트 설정
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'

wordcloud = WordCloud(font_path=font_path,
                      background_color='white',
                      width=800, height=400).generate_from_frequencies(freq)

plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Health information you would like to know', fontsize=20)
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b8b4fa3b-85bd-45c7-a970-5b9cf6ecb5af" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b8b4fa3b-85bd-45c7-a970-5b9cf6ecb5af">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_excel('전체_wordclouds.xlsx')
df.head()
# Out:
#                   Q5(TEXT)
# 0                   종합검진결과
# 1  가족몸이나 내몸에 무슨병이 있는지 궁금하다
# 2                 아픈곳이있으신가
# 3          뇌졸중,고혈압,심근경색,당뇨
# 4                     치매 암

# %%
df = df.fillna('')  # 결측값 제거
all_text = ' '.join(df['Q5(TEXT)'])
from konlpy.tag import Okt
okt = Okt()
nouns = okt.nouns(all_text)
# 자주 등장하지만 의미 없는 단어 추가
stopwords = ['정보', '건강', '데이터', '및', '관련', '등','그냥','현재','상태']
words = [word for word in nouns if word not in stopwords and len(word) > 1]
from nltk import FreqDist
from wordcloud import WordCloud
import matplotlib.pyplot as plt

freq = FreqDist(words)

# 한글 폰트 설정
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'

wordcloud = WordCloud(font_path=font_path,
                      background_color='white',
                      width=800, height=400).generate_from_frequencies(freq)

plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Health information you would like to share or know', fontsize=20)
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# ...
